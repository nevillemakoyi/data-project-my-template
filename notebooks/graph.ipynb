# %% [markdown]
# ### Presentation des graphiques avec Plotly

# %%
import pandas as pd
import plotly.express as px
import numpy as np
from dash import Dash, dcc, html, Input, Output

# %%
data_path = r'C:\Users\nmako\OneDrive\Documents\Data-Science-Projects-Repository\dash-plotly-project\data\processed\Incidents List.xlsx'
data = pd.read_excel(data_path)
df = data.copy()
df
# Out:
#         id  year  month  day   latitude  longitude      act         actor  \
# 0        1  2017      1   17  29.364773  10.481718   Attack  Armed Groups
# 1        2  2021     12   21  25.197497  11.912383  Confine    Government
# 2        3  2020      7   18  29.689688  17.894916   Attack  Armed Groups
# 3        4  2021     11   22  31.813787  19.392226  Confine      Criminal
# 4        5  2019     11   20  24.841812  18.507566   Attack  Armed Groups
# ...    ...   ...    ...  ...        ...        ...      ...           ...
# 3122  3123  2018      8    3  32.100050  10.264589   Attack      Criminal
# 3123  3124  2018      2   17  21.373241  15.825642   Attack      Civilian
# 3124  3125  2019      8   28  26.035983  11.762068   Attack  Armed Groups
# 3125  3126  2017      2   25  29.221043  10.978327  Confine      Criminal
# 3126  3127  2017      1   29  23.454280  15.754741  Confine  Armed Groups
#
#           target functional_location serious_incident  \
# ...

# %%
# number of accidents per month
acc_per_month = df['month'].value_counts().sort_index()
acc_per_month
# Out:
# month
# 1     258
# 2     269
# 3     228
# 4     303
# 5     247
# 6     270
# 7     293
# 8     252
# 9     252
# 10    229
# 11    271
# 12    255
# Name: count, dtype: int64
